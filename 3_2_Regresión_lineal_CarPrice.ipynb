# %% [markdown]
# ![imagen_2021-10-22_074130.png](data:image/png;base64,...)
#
# INGENIERÍA EN DESARROLLO Y GESTIÓN DE SOFTWARE
#
# MATERIA: EXTRACCIÓN DE CONOCIMIENTOS DE BASE DE DATOS
#
# NOMBRE DEL ALUMNO: VICTOR ALDAIR MARTINEZ GAYOSSO
#
# NOMBRE DEL DOCENTE: SALVADOR HERNÁNDEZ MENDOZA
#
# 3.1 ANÁLISIS DEL DATASET CAR PRICE
#
# CUATRIMESTRE: 9º
#
# GRUPO: IDGS-91
#
# FECHA: 22 DE OCTUBRE DE 2021

# %% [markdown]
# Importar librerias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# Cargar el dataset

# %%
dataframe = pd.read_csv("car_price_assignment.csv")

# %% [markdown]
# # Forma del dataset

# %%
dataframe.shape
# Out:
# (205, 26)

# %% [markdown]
# # Primeros registros

# %%
dataframe.head()
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.0
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3       4          2               audi 100 ls  ...      24         30  13950.0
# 4       5          2                audi 100ls  ...      18         22  17450.0
#
# [5 rows x 26 columns]

# %% [markdown]
# # Ultimos registros

# %%
dataframe.tail()
# Out:
#      car_ID  symboling          CarName  ... citympg highwaympg    price
# 200     201         -1  volvo 145e (sw)  ...      23         28  16845.0
# 201     202         -1      volvo 144ea  ...      19         25  19045.0
# 202     203         -1      volvo 244dl  ...      18         23  21485.0
# 203     204         -1        volvo 246  ...      26         27  22470.0
# 204     205         -1      volvo 264gl  ...      19         25  22625.0
#
# [5 rows x 26 columns]

# %% [markdown]
# # Contar valores nulos

# %%
dataframe.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# # Ver informacion del dataset

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# # Promedio de cada columna

# %%
dataframe.mean()
# Out:
# car_ID                103.000000
# symboling               0.834146
# wheelbase              98.756585
# carlength             174.049268
# carwidth               65.907805
# carheight              53.724878
# curbweight           2555.565854
# enginesize            126.907317
# boreratio               3.329756
# stroke                  3.255415
# compressionratio       10.142537
# horsepower            104.117073
# peakrpm              5125.121951
# citympg                25.219512
# highwaympg             30.751220
# price               13276.710571
# dtype: float64

# %%
cols = ['symboling','wheelbase','carlength','carwidth'] # Seleccionamos las columnas
for col in cols:
  print("Columna {} : Mean {}".format(col,dataframe[col].mean()))
  print("Columna {} : Median {}".format(col,dataframe[col].median()))
  print("Columna {} : Mode {}".format(col,dataframe[col].mode()))
# Out:
# Columna symboling : Mean 0.8341463414634146
# Columna symboling : Median 1.0
# Columna symboling : Mode 0    0
# dtype: int64
# Columna wheelbase : Mean 98.75658536585378
# Columna wheelbase : Median 97.0
# Columna wheelbase : Mode 0    94.5
# dtype: float64
# Columna carlength : Mean 174.04926829268305
# Columna carlength : Median 173.2
# Columna carlength : Mode 0    157.3
# dtype: float64
# Columna carwidth : Mean 65.90780487804875
# Columna carwidth : Median 65.5
# Columna carwidth : Mode 0    63.8
# dtype: float64

# %% [markdown]
# # Describir el dataset

# %%
dataframe.describe()
# Out:
#            car_ID   symboling   wheelbase  ...     citympg  highwaympg         price
# count  205.000000  205.000000  205.000000  ...  205.000000  205.000000    205.000000
# mean   103.000000    0.834146   98.756585  ...   25.219512   30.751220  13276.710571
# std     59.322565    1.245307    6.021776  ...    6.542142    6.886443   7988.852332
# min      1.000000   -2.000000   86.600000  ...   13.000000   16.000000   5118.000000
# 25%     52.000000    0.000000   94.500000  ...   19.000000   25.000000   7788.000000
# 50%    103.000000    1.000000   97.000000  ...   24.000000   30.000000  10295.000000
# 75%    154.000000    2.000000  102.400000  ...   30.000000   34.000000  16503.000000
# max    205.000000    3.000000  120.900000  ...   49.000000   54.000000  45400.000000
#
# [8 rows x 16 columns]

# %% [markdown]
# # Correlación entre pares de columnas

# %%
dataframe.corr()
# Out:
#                     car_ID  symboling  ...  highwaympg     price
# car_ID            1.000000  -0.151621  ...    0.011255 -0.109093
# symboling        -0.151621   1.000000  ...    0.034606 -0.079978
# wheelbase         0.129729  -0.531954  ...   -0.544082  0.577816
# carlength         0.170636  -0.357612  ...   -0.704662  0.682920
# carwidth          0.052387  -0.232919  ...   -0.677218  0.759325
# carheight         0.255960  -0.541038  ...   -0.107358  0.119336
# curbweight        0.071962  -0.227691  ...   -0.797465  0.835305
# enginesize       -0.033930  -0.105790  ...   -0.677470  0.874145
# boreratio         0.260064  -0.130051  ...   -0.587012  0.553173
# stroke           -0.160824  -0.008735  ...   -0.043931  0.079443
# compressionratio  0.150276  -0.178515  ...    0.265201  0.067984
# horsepower       -0.015006   0.070873  ...   -0.770544  0.808139
# peakrpm          -0.203789   0.273606  ...   -0.054275 -0.085267
# ...

# %% [markdown]
# # Graficar la correlacion entre columnas en un HEATMAP

# %%
plt.figure(figsize=(16,8))
sns.heatmap(dataframe.corr(),annot=True)
plt.show()

# %% [markdown]
#  # Función para seleccionar columnas con una correlación específica

# %%
def correlation(dataframe,threshold):
  cols_corr = set()
  corr_matrix = dataframe.corr()
  for i in range(len(corr_matrix.columns)):
    for j in range(i):
      if abs(corr_matrix.iloc[i,j]) >= threshold:
        col_name = corr_matrix.columns[i]
        cols_corr.add(col_name)
  return cols_corr

# %%
corr_cols = correlation(dataframe.iloc[:,:-1],0.40)
corr_cols
# Out:
# {'boreratio',
#  'carheight',
#  'carlength',
#  'carwidth',
#  'citympg',
#  'curbweight',
#  'enginesize',
#  'highwaympg',
#  'horsepower',
#  'peakrpm',
#  'wheelbase'}

# %% [markdown]
# # Separar columnas categóricas

# %%
def categorical(dataframe):
    categorical_col = []
    for col in dataframe:
     if dataframe[col].dtype == 'object':
        categorical_col.append(col)
    return categorical_col

# %%
categorical_col = categorical(dataframe)
print(categorical_col)
# Out:
# ['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem']

# %% [markdown]
# # Obtener columnas numericas

# %%
def numerical(dataframe):
  numerical_col = []
  for col in dataframe:
    if dataframe[col].dtype != 'object':
      numerical_col.append(col)
  return numerical_col

# %%
numerical_col = numerical(dataframe)
print(numerical_col)
# Out:
# ['car_ID', 'symboling', 'wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke', 'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price']

# %% [markdown]
# # Graficar una sola columna

# %%
sns.countplot(dataframe['fueltype'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Grafciar todas las comlunas

# %%
i=1
plt.figure(figsize=(30,120))
for col in categorical_col:
  # COUNT PLOT

  plt.subplot(len(categorical_col),2,i)
  sns.countplot(dataframe[col])
  plt.yticks(fontsize=20)
  plt.yticks(fontsize=20)
  plt.xlabel(col,fontsize=20)
  plt.ylabel("count",fontsize=20)
  i = i + 1

  # BOX PLOT

  plt.subplot(len(categorical_col),2,i)
  sns.boxplot(x=dataframe[col], y=dataframe['price'])
  plt.yticks(fontsize=20)
  plt.yticks(fontsize=20)
  plt.xlabel(col,fontsize=20)
  plt.ylabel("price",fontsize=20)
  i = i + 1
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %% [markdown]
# Graficar columnas numéricas

# %%
numerical_col
# Out:
# ['car_ID',
#  'symboling',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
numerical_col.remove('car_ID')
numerical_col.remove('price')

# %%
sns.displot(dataframe['wheelbase'], color ='orange')

# %%
i=1
plt.figure(figsize=(30,100))
for col in numerical_col:
  plt.subplot(len(numerical_col),2,i)
  sns.distplot(dataframe[col],color='red')
  plt.xticks(fontsize=20)
  plt.yticks(fontsize=20)
  plt.xlabel(col,fontsize=20)
  plt.ylabel("count",fontsize=20)
  i = i + 1

  plt.subplot(len(numerical_col),2,i)
  sns.boxplot(dataframe[col],color='blue')
  plt.xticks(fontsize=20)
  plt.yticks(fontsize=20)
  plt.xlabel(col,fontsize=20)
  plt.ylabel("price",fontsize=20)
  i = i + 1
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %% [markdown]
# # Precio

# %%
sns.displot(dataframe['price'],color='black',kde=True)

# %%
dataframe['price'].skew()
# Out:
# 1.7776781560914454

# %% [markdown]
# # Normalizar con **Min-Max**

# %%
def minmax_norm(dataframe):
  return (dataframe - dataframe.min()) / (dataframe.max() - dataframe.min())

# %%
print(dataframe['price'])
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
temporal = minmax_norm(dataframe['price'])
print(temporal)
# Out:
# 0      0.207959
# 1      0.282558
# 2      0.282558
# 3      0.219254
# 4      0.306142
#          ...
# 200    0.291123
# 201    0.345738
# 202    0.406311
# 203    0.430763
# 204    0.434611
# Name: price, Length: 205, dtype: float64

# %%
sns.displot(dataframe['price'],color='black',kde=True)
sns.displot(temporal, color='red', kde=True)

# %% [markdown]
# # Transformación log

# %% [markdown]
# Importar librerias

# %%
from sklearn.preprocessing import FunctionTransformer

# %% [markdown]
# # Selecionar función

# %%
ft = FunctionTransformer(func=np.log)

# %%
#temporal2 = ft.fit_transform(dataframe['price'])
dataframe['price'] = ft.fit_transform(dataframe['price'])

# %%
sns.displot(temporal2,color='black',kde=True)

# %% [markdown]
# # Columnas categóricas a numericas

# %%
import pandas as pd

# %%
dataframe_cat = pd.DataFrame({
    'datos':[46,89,45],
    'edad':[10,23,46],
    'genero':['f','m','f']
    })

# %%
dataframe_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   datos   3 non-null      int64
#  1   edad    3 non-null      int64
#  2   genero  3 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 200.0+ bytes

# %%
dataframe_cat.describe()
# Out:
#            datos       edad
# count   3.000000   3.000000
# mean   60.000000  26.333333
# std    25.119713  18.230012
# min    45.000000  10.000000
# 25%    45.500000  16.500000
# 50%    46.000000  23.000000
# 75%    67.500000  34.500000
# max    89.000000  46.000000

# %%
pd.get_dummies(dataframe_cat,columns=['genero'],drop_first=False)
# Out:
#    datos  edad  genero_f  genero_m
# 0     46    10         1         0
# 1     89    23         0         1
# 2     45    46         1         0

# %%
dataframe_cat = pd.get_dummies(dataframe_cat,columns=['genero'],drop_first=True)

# %%
dataframe_cat.describe()
# Out:
#            datos       edad  genero_m
# count   3.000000   3.000000  3.000000
# mean   60.000000  26.333333  0.333333
# std    25.119713  18.230012  0.577350
# min    45.000000  10.000000  0.000000
# 25%    45.500000  16.500000  0.000000
# 50%    46.000000  23.000000  0.000000
# 75%    67.500000  34.500000  0.500000
# max    89.000000  46.000000  1.000000

# %% [markdown]
# # Multiples columnas categóricas

# %%
dataframe_cat2 = pd.DataFrame({
    'datos':[46,89,45],
    'edad':[10,23,46],
    'genero':['f','m','f'],
    'estudio':['si','no','si']
    })

# %%
dataframe_cat2
# Out:
#    datos  edad genero estudio
# 0     46    10      f      si
# 1     89    23      m      no
# 2     45    46      f      si

# %%
pd.get_dummies(dataframe_cat2, columns=['genero','estudio'],prefix='dummy',drop_first=True)
# Out:
#    datos  edad  dummy_m  dummy_si
# 0     46    10        0         1
# 1     89    23        1         0
# 2     45    46        0         1

# %% [markdown]
# # Multiples columnas categoricas y multiples valores

# %%
dataframe_cat2 = pd.DataFrame({
    'salario':[1000,4000,6000],
    'edad':[10,23,46],
    'genero':['femenino','masculino','femenino'],
    'estudia':['si','no','si'],
    'nivel_estudio':['primaria','secundaria','universidad']
    })

# %%
dataframe_cat2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   salario        3 non-null      int64
#  1   edad           3 non-null      int64
#  2   genero         3 non-null      object
#  3   estudia        3 non-null      object
#  4   nivel_estudio  3 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 248.0+ bytes

# %%
dataframe_cat2 = pd.get_dummies(dataframe_cat2,columns=['genero','estudia','nivel_estudio'])

# %%
dataframe_cat2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   salario                    3 non-null      int64
#  1   edad                       3 non-null      int64
#  2   genero_femenino            3 non-null      uint8
#  3   genero_masculino           3 non-null      uint8
#  4   estudia_no                 3 non-null      uint8
#  5   estudia_si                 3 non-null      uint8
#  6   nivel_estudio_primaria     3 non-null      uint8
#  7   nivel_estudio_secundaria   3 non-null      uint8
#  8   nivel_estudio_universidad  3 non-null      uint8
# dtypes: int64(2), uint8(7)
# memory usage: 197.0 bytes

# %% [markdown]
# # CONCLUSIÓN
#
#
# Como conclusión se deduce que Google Colab facilita aún el procesamiento de la información y el compartirla con tus colaboradores. Además, tienes a tu servicio la capacidad de cómputo de Google, por lo que, si estás utilizando un equipo con pocos recursos, esta es la herramienta ideal para desarrollar tus algoritmos. Así mismo lo visto en esta actividad fue de gran ayuda ya que vimos el cómo realizar Convertir columnas categóricas en columnas numéricas al igual dividir el dataframe en train y test y por ultimo al como realizar una regresión lineal con todas las columnas numéricas.
